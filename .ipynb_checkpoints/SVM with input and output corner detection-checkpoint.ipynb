# %%
from PIL import Image
import numpy as np
import pandas as pd
from sklearn.svm import SVC
import cv2
import glob
import math
import os
import numpy as np
from sklearn import svm
from sklearn.metrics import accuracy_score
from matplotlib import pyplot as plt

# %%
def image_to_feature_vector(image, size=(300, 300)):
    return cv2.resize(image, size)

# %%
def shi_tomasi_corner_detection(image,corners=50,Quality_Level=0.01,Euclidean_Distance=10):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    corners = cv2.goodFeaturesToTrack(gray,corners,Quality_Level,Euclidean_Distance)
    corners = np.int0(corners)
    clr=(0,0,255)
    for i in corners:
        x,y = i.ravel()
        cv2.circle(image,(x,y),3,clr,-1)
    return image

# %%
#input of pothole images with corner detection
number = 1
train = []
pot = 343

for i in range(pot):
    var = "C:/Users/subhashis sengupta/Desktop/pothole images/trial/pothole/" + str(number) + ".jpg"
    pic = cv2.imread(var)
    corner = image_to_feature_vector(pic)
    corner1 = shi_tomasi_corner_detection(corner)
    data = np.array(corner1)
    flattened = data.flatten()
    train.append(flattened)
    number = number + 1

# %%
train
# Out:
# [array([180, 196, 203, ...,  88,  96, 109], dtype=uint8),
#  array([77, 72, 87, ..., 64, 66, 76], dtype=uint8),
#  array([101, 100, 100, ..., 175, 177, 178], dtype=uint8),
#  array([ 4,  2,  2, ..., 64, 60, 59], dtype=uint8),
#  array([76, 76, 76, ..., 57, 57, 57], dtype=uint8),
#  array([31, 43, 61, ..., 11, 15, 19], dtype=uint8),
#  array([34, 52, 58, ..., 67, 70, 74], dtype=uint8),
#  array([178, 164, 158, ..., 124, 119, 121], dtype=uint8),
#  array([42, 32, 14, ..., 34, 34, 34], dtype=uint8),
#  array([13, 10, 12, ...,  4,  2,  1], dtype=uint8),
#  array([ 93,  87,  82, ..., 121, 124, 129], dtype=uint8),
#  array([240, 230, 230, ...,  90, 103, 115], dtype=uint8),
#  array([141, 145, 150, ...,  78,  78,  78], dtype=uint8),
#  array([ 83,  92,  96, ..., 188, 194, 193], dtype=uint8),
#  array([218, 218, 218, ..., 168, 172, 183], dtype=uint8),
#  array([148, 141, 121, ...,  76,  67,  61], dtype=uint8),
#  array([107, 104, 109, ..., 167, 163, 162], dtype=uint8),
#  array([ 59,  58,  52, ..., 111, 123, 125], dtype=uint8),
#  array([110,  98,  88, ..., 122, 110, 107], dtype=uint8),
#  array([145, 150, 153, ..., 164, 166, 171], dtype=uint8),
#  array([129, 122, 115, ...,  41,  43,  43], dtype=uint8),
#  array([50, 79, 88, ..., 94, 99, 98], dtype=uint8),
#  array([247, 242, 241, ..., 121, 114, 117], dtype=uint8),
#  array([164, 176, 176, ...,  82,  92,  85], dtype=uint8),
#  array([237, 236, 240, ..., 142, 143, 147], dtype=uint8),
#  array([245, 222, 196, ..., 128, 128, 128], dtype=uint8),
#  array([85, 79, 80, ..., 60, 54, 59], dtype=uint8),
#  array([157, 158, 162, ...,  99,  86,  84], dtype=uint8),
#  array([127, 146, 172, ..., 156, 150, 155], dtype=uint8),
#  array([30, 52, 64, ..., 53, 47, 46], dtype=uint8),
#  array([156, 185, 189, ..., 124, 151, 165], dtype=uint8),
#  array([120, 126, 129, ..., 158, 155, 150], dtype=uint8),
#  array([70, 61, 64, ..., 64, 65, 63], dtype=uint8),
#  array([103,  99,  98, ..., 149, 155, 154], dtype=uint8),
#  array([71, 73, 74, ..., 79, 76, 71], dtype=uint8),
#  array([250, 252, 248, ...,  72,  66,  67], dtype=uint8),
#  array([168, 175, 168, ..., 151, 146, 148], dtype=uint8),
#  array([245, 246, 243, ...,  89,  87,  82], dtype=uint8),
#  array([69, 76, 79, ..., 83, 88, 89], dtype=uint8),
#  array([253, 254, 252, ..., 139, 147, 150], dtype=uint8),
#  array([132, 150, 194, ...,  63,  57,  46], dtype=uint8),
#  array([129, 132, 133, ..., 147, 149, 159], dtype=uint8),
#  array([123, 120, 115, ...,  85,  76,  73], dtype=uint8),
#  array([73, 76, 61, ..., 36, 36, 46], dtype=uint8),
#  array([178, 167, 169, ..., 186, 184, 184], dtype=uint8),
#  array([  6,   9,   8, ..., 147, 163, 152], dtype=uint8),
#  array([ 24,  45,  36, ..., 125, 128, 136], dtype=uint8),
#  array([129, 134, 133, ...,  99, 100,  97], dtype=uint8),
#  array([171, 173, 174, ...,  82,  85,  76], dtype=uint8),
#  array([158, 151, 142, ..., 186, 205, 220], dtype=uint8),
#  array([161, 156, 155, ..., 140, 145, 144], dtype=uint8),
#  array([ 83,  34,  30, ..., 169, 171, 179], dtype=uint8),
#  array([ 48,  59,  57, ..., 105,  84,  82], dtype=uint8),
#  array([ 71,  77,  84, ..., 128, 132, 143], dtype=uint8),
#  array([172, 170, 170, ...,  31,  18,  15], dtype=uint8),
#  array([ 70, 131, 107, ...,  41,  43,  43], dtype=uint8),
#  array([ 84, 116, 151, ..., 109, 114, 123], dtype=uint8),
#  array([192, 192, 192, ..., 163, 167, 170], dtype=uint8),
#  array([220, 221, 220, ..., 129, 130, 131], dtype=uint8),
#  array([160, 141, 133, ...,  98,  90,  90], dtype=uint8),
#  array([ 38,  71,  64, ..., 131, 130, 134], dtype=uint8),
#  array([251, 235, 219, ...,  29,  38,  47], dtype=uint8),
#  array([254, 251, 243, ..., 148, 173, 193], dtype=uint8),
#  array([216, 201, 199, ..., 188, 171, 168], dtype=uint8),
#  array([ 18,  44,  40, ..., 130, 131, 131], dtype=uint8),
#  array([164, 161, 163, ..., 173, 164, 161], dtype=uint8),
#  array([89, 93, 98, ..., 52, 57, 59], dtype=uint8),
#  array([249, 249, 249, ..., 139, 142, 147], dtype=uint8),
#  array([210, 230, 231, ...,  46,  49,  57], dtype=uint8),
#  array([131, 110,  95, ..., 104, 113, 117], dtype=uint8),
#  array([103,  55,  28, ..., 140, 138, 144], dtype=uint8),
#  array([130, 147, 154, ..., 142, 149, 164], dtype=uint8),
#  array([188, 135, 127, ..., 223, 220, 229], dtype=uint8),
#  array([54, 69, 72, ..., 87, 82, 84], dtype=uint8),
#  array([83, 88, 89, ..., 36, 40, 45], dtype=uint8),
#  array([ 53,  98,  71, ..., 158, 156, 155], dtype=uint8),
#  array([ 96, 105, 109, ..., 184, 186, 187], dtype=uint8),
#  array([20, 42, 47, ..., 76, 86, 93], dtype=uint8),
#  array([ 33,  85,  59, ...,  97, 105,  96], dtype=uint8),
#  array([118, 119, 124, ...,  99,  94,  99], dtype=uint8),
#  array([ 44,  58,  78, ..., 159, 159, 159], dtype=uint8),
#  array([  6,   4,   4, ..., 113, 117, 116], dtype=uint8),
#  array([138, 130, 141, ...,  71,  88, 101], dtype=uint8),
#  array([ 46,  25,  52, ...,  76,  80, 100], dtype=uint8),
#  array([104, 118, 124, ...,  87,  99, 101], dtype=uint8),
#  array([  0,   0, 255, ...,  63,  63,  70], dtype=uint8),
#  array([125, 125, 160, ...,  73,  59,  65], dtype=uint8),
#  array([179, 164, 147, ...,  87,  84,  79], dtype=uint8),
#  array([107, 114, 117, ...,  85, 116, 148], dtype=uint8),
#  array([ 96,  91,  90, ..., 144, 144, 144], dtype=uint8),
#  array([48, 50, 51, ..., 38, 37, 41], dtype=uint8),
#  array([ 64,  65,  63, ..., 142, 130, 122], dtype=uint8),
#  array([155, 175, 182, ..., 133, 135, 153], dtype=uint8),
#  array([101, 102, 100, ..., 155, 153, 152], dtype=uint8),
#  array([150, 158, 157, ...,  90,  97, 106], dtype=uint8),
#  array([ 48,  58,  68, ...,  99,  83, 106], dtype=uint8),
#  array([108, 101, 105, ..., 115, 113, 113], dtype=uint8),
#  array([75, 65, 71, ..., 73, 78, 77], dtype=uint8),
#  array([205, 194, 215, ...,  63,  52,  48], dtype=uint8),
#  array([147, 169, 211, ...,  42,  44,  44], dtype=uint8),
#  array([118, 123, 126, ...,  92,  91,  87], dtype=uint8),
#  array([ 92, 100, 103, ...,  87,  89,  99], dtype=uint8),
#  array([115, 131, 160, ..., 137, 131, 120], dtype=uint8),
#  array([222, 209, 206, ...,  68,  61,  58], dtype=uint8),
#  array([185, 190, 194, ..., 151, 153, 161], dtype=uint8),
#  array([162, 185, 181, ..., 112, 114, 125], dtype=uint8),
#  array([ 53,  46,  47, ..., 121, 121, 121], dtype=uint8),
#  array([175, 157, 146, ..., 129, 135, 133], dtype=uint8),
#  array([234, 227, 222, ...,  91, 111, 128], dtype=uint8),
#  array([88, 89, 93, ..., 67, 54, 62], dtype=uint8),
#  array([195, 197, 200, ..., 138, 142, 153], dtype=uint8),
#  array([76, 80, 75, ..., 84, 88, 93], dtype=uint8),
#  array([217, 218, 209, ..., 128, 125, 120], dtype=uint8),
#  array([135, 191, 220, ...,  62,  61,  70], dtype=uint8),
#  array([227, 222, 213, ..., 113, 108, 105], dtype=uint8),
#  array([ 17,  19,  15, ..., 112, 101, 101], dtype=uint8),
#  array([91, 75, 72, ...,  0,  0,  0], dtype=uint8),
#  array([  9,  37,  23, ..., 158, 166, 165], dtype=uint8),
#  array([158, 150, 143, ...,  84,  79,  80], dtype=uint8),
#  array([171, 190, 169, ..., 165, 165, 171], dtype=uint8),
#  array([173, 193, 195, ...,  85,  94,  97], dtype=uint8),
#  array([197, 183, 171, ...,  10,  12,  21], dtype=uint8),
#  array([242, 244, 245, ...,  83,  88,  93], dtype=uint8),
#  array([55, 67, 71, ..., 34, 40, 39], dtype=uint8),
#  array([ 37,  47,  91, ...,  99,  98, 100], dtype=uint8),
#  array([ 91, 104, 118, ...,  71,  71,  71], dtype=uint8),
#  array([183, 193, 186, ..., 217, 224, 231], dtype=uint8),
#  array([120, 124, 128, ...,  71,  65,  66], dtype=uint8),
#  array([ 47,  48,  52, ..., 102, 112, 119], dtype=uint8),
#  array([63, 64, 66, ..., 56, 58, 63], dtype=uint8),
#  array([  0,   1,   2, ..., 117, 124, 133], dtype=uint8),
#  array([96, 81, 84, ...,  0,  1,  0], dtype=uint8),
#  array([255, 254, 254, ...,  72,  72,  67], dtype=uint8),
#  array([231, 226, 227, ...,   7,   8,   8], dtype=uint8),
#  array([123, 123, 123, ..., 106, 118, 124], dtype=uint8),
#  array([61, 60, 46, ..., 23, 24, 28], dtype=uint8),
#  array([254, 250, 249, ...,  99, 109, 109], dtype=uint8),
#  array([205, 164, 139, ...,  84,  86,  87], dtype=uint8),
#  array([193, 197, 191, ..., 132, 131, 133], dtype=uint8),
#  array([144, 135, 131, ..., 114, 118, 119], dtype=uint8),
#  array([146,  98,  86, ...,  74,  37,  53], dtype=uint8),
#  array([246, 242, 243, ..., 112, 116, 120], dtype=uint8),
#  array([38, 52, 50, ..., 40, 41, 42], dtype=uint8),
#  array([252, 254, 254, ...,  22,  23,  27], dtype=uint8),
#  array([207, 191, 185, ...,  55,  49,  50], dtype=uint8),
#  array([202, 200, 200, ..., 148, 162, 177], dtype=uint8),
#  array([56, 46, 36, ..., 77, 76, 78], dtype=uint8),
#  array([219, 210, 206, ..., 152, 152, 152], dtype=uint8),
#  array([ 97,  99, 107, ..., 185, 196, 210], dtype=uint8),
#  array([25, 34, 48, ..., 68, 65, 61], dtype=uint8),
#  array([19, 33, 29, ..., 57, 71, 77], dtype=uint8),
#  array([226, 210, 181, ...,  42,  54,  73], dtype=uint8),
#  array([254, 246, 233, ...,  10,  18,  18], dtype=uint8),
#  array([132, 120, 110, ..., 125, 130, 135], dtype=uint8),
#  array([249, 249, 252, ...,  70,  67,  69], dtype=uint8),
#  array([161, 180, 197, ...,  83,  92, 102], dtype=uint8),
#  array([225, 224, 223, ..., 155, 171, 183], dtype=uint8),
#  array([171, 187, 199, ..., 114, 120, 125], dtype=uint8),
#  array([ 4, 56, 56, ..., 69, 76, 85], dtype=uint8),
#  array([191, 186, 196, ..., 170, 166, 172], dtype=uint8),
#  array([152, 179, 199, ..., 140, 152, 154], dtype=uint8),
#  array([ 91,  94,  85, ..., 106,  99,  85], dtype=uint8),
#  array([61, 65, 70, ..., 68, 65, 67], dtype=uint8),
#  array([246, 246, 246, ...,  63,  64,  62], dtype=uint8),
#  array([132, 142, 136, ...,  83,  62,  60], dtype=uint8),
#  array([34, 31, 26, ..., 33, 26, 16], dtype=uint8),
#  array([ 9, 34,  8, ...,  0,  0,  0], dtype=uint8),
#  array([218, 220, 221, ..., 110, 114, 119], dtype=uint8),
#  array([255, 255, 255, ..., 255, 255, 255], dtype=uint8),
#  array([ 2,  0,  1, ..., 81, 84, 88], dtype=uint8),
#  array([ 34,  39,  39, ..., 156, 152, 150], dtype=uint8),
#  array([ 4, 56, 56, ..., 69, 76, 85], dtype=uint8),
#  array([50, 90, 79, ..., 97, 94, 96], dtype=uint8),
#  array([ 24,  82,  49, ..., 177, 180, 186], dtype=uint8),
#  array([20, 31, 35, ..., 47, 44, 30], dtype=uint8),
#  array([ 55,  66,  80, ..., 113, 109, 104], dtype=uint8),
#  array([ 1, 28,  9, ..., 45, 37, 37], dtype=uint8),
#  array([59, 70, 74, ..., 52, 54, 55], dtype=uint8),
#  array([183, 178, 183, ...,  42,  41,  41], dtype=uint8),
#  array([102, 104, 112, ...,  53,  65,  79], dtype=uint8),
#  array([ 95, 100,  98, ...,  75,  77,  78], dtype=uint8),
#  array([ 47,  55,  72, ..., 117, 113, 112], dtype=uint8),
#  array([100,  89,  85, ...,  42,  37,  37], dtype=uint8),
#  array([191, 209, 220, ...,  78,  75,  83], dtype=uint8),
#  array([59, 60, 64, ..., 33, 32, 36], dtype=uint8),
#  array([ 68, 118, 114, ..., 165, 173, 175], dtype=uint8),
#  array([35, 37, 45, ..., 76, 80, 85], dtype=uint8),
#  array([ 58,  58,  76, ..., 158, 157, 159], dtype=uint8),
#  array([39, 44, 43, ..., 26, 31, 34], dtype=uint8),
#  array([214, 216, 217, ..., 114, 117, 122], dtype=uint8),
#  array([ 31,  40,  50, ..., 142, 141, 146], dtype=uint8),
#  array([ 30,  34,  15, ..., 169, 171, 171], dtype=uint8),
#  array([ 47,  43,  38, ..., 184, 192, 192], dtype=uint8),
#  array([127, 135, 133, ...,  85,  86,  87], dtype=uint8),
#  array([111, 124, 110, ...,  67,  76,  79], dtype=uint8),
#  array([ 82, 106, 136, ...,  80,  83,  88], dtype=uint8),
#  array([246, 233, 225, ...,  56,  54,  58], dtype=uint8),
#  array([11, 67, 58, ..., 44, 51, 54], dtype=uint8),
#  array([  5,  12,  15, ..., 118, 113, 110], dtype=uint8),
#  array([ 31,  19,  13, ..., 119, 138, 160], dtype=uint8),
#  array([ 28,  41,  33, ..., 152, 152, 152], dtype=uint8),
#  array([145, 155, 169, ...,   0,   0, 255], dtype=uint8),
#  array([203, 189, 183, ..., 104, 115, 123], dtype=uint8),
#  array([157, 192, 202, ..., 181, 173, 173], dtype=uint8),
#  array([151, 149, 150, ...,  90,  92,  95], dtype=uint8),
#  array([115, 114, 116, ...,  80,  80,  80], dtype=uint8),
#  array([157, 159, 167, ..., 140, 139, 143], dtype=uint8),
#  array([240, 232, 225, ...,  36,  40,  45], dtype=uint8),
#  array([142, 136, 123, ..., 139, 144, 154], dtype=uint8),
#  array([189, 155, 125, ...,  71,  73,  71], dtype=uint8),
#  array([176, 184, 197, ..., 110, 114, 119], dtype=uint8),
#  array([84, 89, 87, ..., 50, 49, 53], dtype=uint8),
#  array([186, 190, 195, ..., 189, 198, 205], dtype=uint8),
#  array([ 10,  15,  13, ..., 172, 166, 169], dtype=uint8),
#  array([145, 143, 142, ..., 125, 129, 123], dtype=uint8),
#  array([  2,   9,   4, ..., 137, 133, 128], dtype=uint8),
#  array([129, 131, 142, ..., 138, 155, 174], dtype=uint8),
#  array([96, 85, 61, ..., 92, 86, 87], dtype=uint8),
#  array([219, 216, 203, ..., 107, 115, 122], dtype=uint8),
#  array([255, 255, 255, ...,  60,  63,  67], dtype=uint8),
#  array([ 66,  80,  79, ..., 108, 108, 102], dtype=uint8),
#  array([139, 137, 133, ..., 103, 113, 113], dtype=uint8),
#  array([208, 204, 206, ..., 140, 138, 138], dtype=uint8),
#  array([154, 132, 120, ...,  94,  94, 106], dtype=uint8),
#  array([254, 254, 254, ...,  58,  65,  74], dtype=uint8),
#  array([136, 137, 131, ...,  55,  75,  73], dtype=uint8),
#  array([196, 189, 186, ..., 202, 209, 213], dtype=uint8),
#  array([ 85, 117, 113, ..., 149, 147, 147], dtype=uint8),
#  array([90, 89, 98, ..., 38, 35, 38], dtype=uint8),
#  array([224, 204, 198, ...,  96,  87, 108], dtype=uint8),
#  array([110, 144, 124, ..., 123, 103,  88], dtype=uint8),
#  array([21, 12,  9, ..., 72, 77, 76], dtype=uint8),
#  array([210, 178, 153, ..., 179, 182, 187], dtype=uint8),
#  array([ 67,  77,  87, ...,  94, 110, 123], dtype=uint8),
#  array([37, 40, 50, ..., 45, 71, 88], dtype=uint8),
#  array([255, 255, 255, ..., 123, 137, 143], dtype=uint8),
#  array([174, 111,  67, ...,  37,  42,  43], dtype=uint8),
#  array([123, 123, 123, ...,  82,  81,  91], dtype=uint8),
#  array([86, 75, 71, ..., 17, 63, 85], dtype=uint8),
#  array([126, 123, 118, ...,  93,  90,  86], dtype=uint8),
#  array([232, 230, 229, ...,  60,  62,  62], dtype=uint8),
#  array([ 32,  36,  56, ...,  97, 102, 101], dtype=uint8),
#  array([153, 148, 147, ..., 202, 199, 198], dtype=uint8),
#  array([66, 71, 72, ..., 66, 71, 86], dtype=uint8),
#  array([104, 115, 147, ..., 115, 120, 121], dtype=uint8),
#  array([53, 66, 34, ..., 14, 22, 22], dtype=uint8),
#  array([103, 100,  92, ...,  90,  92,  92], dtype=uint8),
#  array([255, 252, 255, ..., 254, 254, 254], dtype=uint8),
#  array([114, 104,  97, ...,  21,  20,  15], dtype=uint8),
#  array([230, 232, 232, ...,  21,  15,  15], dtype=uint8),
#  array([77, 88, 92, ..., 89, 89, 95], dtype=uint8),
#  array([214, 209, 206, ..., 109, 112, 113], dtype=uint8),
#  array([14, 53, 47, ..., 72, 85, 83], dtype=uint8),
#  array([162, 168, 166, ..., 159, 160, 161], dtype=uint8),
#  array([0, 0, 0, ..., 1, 2, 3], dtype=uint8),
#  array([137, 141, 152, ..., 140, 143, 151], dtype=uint8),
#  array([167, 148, 127, ...,  30,  28,  24], dtype=uint8),
#  array([85, 82, 67, ..., 51, 51, 41], dtype=uint8),
#  array([206, 194, 184, ...,  81,  81,  86], dtype=uint8),
#  array([227, 226, 222, ...,  42,  44,  42], dtype=uint8),
#  array([113, 117, 149, ...,  47,  44,  46], dtype=uint8),
#  array([ 57, 111, 101, ...,  85,  80,  74], dtype=uint8),
#  array([208, 224, 226, ..., 161, 185, 197], dtype=uint8),
#  array([84, 82, 72, ..., 28, 43, 37], dtype=uint8),
#  array([172, 170, 160, ..., 126, 130, 135], dtype=uint8),
#  array([ 66,  95, 100, ...,  76,  69,  72], dtype=uint8),
#  array([226, 240, 239, ..., 195, 197, 195], dtype=uint8),
#  array([215, 213, 213, ...,  41,  50,  57], dtype=uint8),
#  array([252, 254, 252, ..., 179, 210, 233], dtype=uint8),
#  array([ 90,  92, 102, ..., 158, 167, 173], dtype=uint8),
#  array([109, 116, 119, ..., 139, 155, 163], dtype=uint8),
#  array([ 14,  16,  16, ..., 140, 140, 146], dtype=uint8),
#  array([137, 140, 148, ...,  86,  98, 108], dtype=uint8),
#  array([193, 187, 182, ..., 121, 121, 121], dtype=uint8),
#  array([  5,   5,   5, ..., 152, 159, 179], dtype=uint8),
#  array([ 8, 10, 10, ..., 37, 33, 30], dtype=uint8),
#  array([116, 131, 134, ..., 153, 152, 138], dtype=uint8),
#  array([178, 187, 191, ...,  48,  43,  42], dtype=uint8),
#  array([115, 117, 117, ...,  94,  98,  99], dtype=uint8),
#  array([182, 177, 178, ..., 150, 146, 145], dtype=uint8),
#  array([170, 151, 143, ...,  57,  81,  87], dtype=uint8),
#  array([11, 11, 11, ..., 41, 39, 39], dtype=uint8),
#  array([ 4,  2,  2, ..., 64, 60, 59], dtype=uint8),
#  array([29, 19, 19, ..., 26,  5,  7], dtype=uint8),
#  array([  0,   0, 255, ..., 108, 129, 130], dtype=uint8),
#  array([253, 219, 196, ...,  85,  77,  87], dtype=uint8),
#  array([125, 110, 108, ..., 131, 128, 159], dtype=uint8),
#  array([126, 113,  92, ...,  31,  41,  54], dtype=uint8),
#  array([188, 206, 217, ...,  71,  74,  82], dtype=uint8),
#  array([ 31,  34,  38, ..., 147, 208, 228], dtype=uint8),
#  array([ 96, 101, 100, ..., 104, 105, 101], dtype=uint8),
#  array([175, 168, 171, ..., 121, 117, 122], dtype=uint8),
#  array([84, 87, 99, ..., 39, 43, 56], dtype=uint8),
#  array([138, 154, 151, ..., 150, 158, 172], dtype=uint8),
#  array([153, 150, 145, ...,  40,  37,  33], dtype=uint8),
#  array([34, 39, 39, ..., 25, 25, 25], dtype=uint8),
#  array([0, 0, 0, ..., 0, 0, 0], dtype=uint8),
#  array([17, 39, 38, ..., 88, 83, 82], dtype=uint8),
#  array([ 52,  56,  57, ..., 130, 135, 133], dtype=uint8),
#  array([231, 229, 232, ..., 145, 148, 156], dtype=uint8),
#  array([253, 217, 179, ...,  19,  13,   8], dtype=uint8),
#  array([149, 140, 136, ..., 133, 131, 137], dtype=uint8),
#  array([115, 120, 119, ...,  99, 104, 103], dtype=uint8),
#  array([231, 219, 215, ...,  61,  64,  68], dtype=uint8),
#  array([129, 133, 129, ..., 144, 146, 146], dtype=uint8),
#  array([ 48,  48,  48, ..., 139, 163, 175], dtype=uint8),
#  array([ 43,  55,  35, ..., 144, 147, 132], dtype=uint8),
#  array([255, 255, 255, ..., 108, 112, 117], dtype=uint8),
#  array([67, 92, 88, ..., 23, 29, 42], dtype=uint8),
#  array([141, 134, 141, ..., 152, 152, 152], dtype=uint8),
#  array([129, 135, 134, ...,  56,  56,  55], dtype=uint8),
#  array([251, 252, 250, ..., 169, 142, 138], dtype=uint8),
#  array([129, 124, 125, ..., 108, 109, 121], dtype=uint8),
#  array([234, 237, 238, ..., 100,  99, 107], dtype=uint8),
#  array([131, 144, 179, ..., 199, 218, 226], dtype=uint8),
#  array([138, 147, 160, ...,  86,  93,  96], dtype=uint8),
#  array([ 18, 127,  79, ..., 172, 169, 165], dtype=uint8),
#  array([63, 97, 96, ..., 79, 71, 81], dtype=uint8),
#  array([35, 37, 45, ..., 76, 80, 85], dtype=uint8),
#  array([152, 168, 181, ..., 114, 109, 109], dtype=uint8),
#  array([135, 175, 194, ..., 154, 156, 157], dtype=uint8),
#  array([109, 114, 113, ..., 121, 135, 141], dtype=uint8),
#  array([160, 169, 177, ..., 104, 118, 130], dtype=uint8),
#  array([132,  51,  36, ...,  41,  41,  41], dtype=uint8),
#  array([69, 69, 69, ..., 59, 64, 64], dtype=uint8),
#  array([65, 60, 59, ..., 22, 10,  8], dtype=uint8),
#  array([ 77,  81,  76, ..., 112, 115, 122], dtype=uint8),
#  array([203, 205, 205, ..., 210, 219, 219], dtype=uint8),
#  array([116, 161, 138, ...,  42,  44,  52], dtype=uint8),
#  array([253, 255, 255, ...,  70,  54,  42], dtype=uint8),
#  array([160, 157, 153, ..., 130, 131, 127], dtype=uint8),
#  array([50, 82, 71, ..., 36, 45, 48], dtype=uint8),
#  array([  0,   3,   8, ..., 103,  96,  99], dtype=uint8),
#  array([169, 167, 156, ..., 231, 227, 226], dtype=uint8),
#  array([252, 254, 248, ..., 187, 204, 207], dtype=uint8),
#  array([ 65,  86,  87, ..., 100, 103, 108], dtype=uint8),
#  array([223, 221, 233, ..., 116, 111, 113], dtype=uint8),
#  array([68, 68, 74, ..., 28, 29, 33], dtype=uint8),
#  array([141, 138, 134, ..., 105, 102,  98], dtype=uint8),
#  array([ 31,  37,  46, ..., 106,  99, 102], dtype=uint8),
#  array([155, 135, 137, ..., 169, 170, 168], dtype=uint8),
#  array([  0,   0, 255, ..., 149, 141, 149], dtype=uint8),
#  array([153, 172, 177, ...,  43,  48,  57], dtype=uint8)]

# %%
#input of plain images with corner detection
number = 1
npot = 355

for i in range(npot):
    var = "C:/Users/subhashis sengupta/Desktop/pothole images/trial/plain/" + str(number) + ".jpg"
    pic = cv2.imread(var)
    corner = image_to_feature_vector(pic)
    corner1 = shi_tomasi_corner_detection(corner)
    data = np.array(corner1)
    flattened = data.flatten()
    train.append(flattened)
    number = number + 1

# %%
y = []
for i in range(pot):
    y.append(1)
for i in range(npot):
    y.append(0)

# %%
meh=SVC(probability=True)
meh.fit(train,y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=True, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
#output of pothole images with corner detection
number = 1
test = []
pot = 8

for i in range(pot):
    var = "C:/Users/subhashis sengupta/Desktop/pothole images/My Dataset/test/Pothole/" + str(number) + ".jpg"
    pic = cv2.imread(var)
    corner = image_to_feature_vector(pic)
    corner1 = shi_tomasi_corner_detection(corner)
    cv2.imshow('og',corner)
    cv2.imshow('canny',corner1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    data = np.array(corner1)
    flattened = data.flatten()
    test.append(flattened)
    number = number + 1 

print(meh.predict(test))
# Out:
# [1 1 1 1 1 1 0 0]

# %%
#output of pothole images with corner detection
number = 1
test = []
npot = 8

for i in range(npot):
    var = "C:/Users/subhashis sengupta/Desktop/pothole images/My Dataset/test/Plain/" + str(number) + ".jpg"
    pic = cv2.imread(var)
    corner = image_to_feature_vector(pic)
    corner1 = shi_tomasi_corner_detection(corner)
    cv2.imshow('og',corner)
    cv2.imshow('canny',corner1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    data = np.array(corner1)
    flattened = data.flatten()
    test.append(flattened)
    number = number + 1 

print(meh.predict(test))
# Out:
# [1 1 1 1 0 0 0 0]
